# %%
# !pip install baidu-aip

# %%
# !pip install python-docx
# Out:
# ...
#   Created wheel for docx: filename=docx-0.2.4-cp37-none-any.whl size=53935 sha256=7c09ce6a219710d134410fe530b5b5bf191de18b622e720e216e22fdb6e4e746
#   Stored in directory: C:\Users\swl\AppData\Local\pip\Cache\wheels\cc\8d\09\563edfd874a35c0c7ed129b6c4fa890efa4c26458bdec6ffc1
# Successfully built docx
# ...

# %%
import python
from docx import Document
doc = Document("C:/Users/swl/Desktop/image.docx")
blip = doc.inline_shapes[0]._inline.graphic.graphicData.pic.blipFill.blip
rID = blip.embed
document_part = doc.part
image_part = document_part.related_parts[rID]

fr = open("test.png", "wb")
fr.write(image_part._blob)
fr.close()
# Out:
#   File "<ipython-input-14-36c80a3b9b49>", line 1
#     import python-opencv
#                  ^
# SyntaxError: invalid syntax

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
# """
# Created on Tue Jun 12 09:37:38 2018
# 利用百度api实现图片文本识别
# @author: XnCSD
# """

import glob
from os import path
import os
from aip import AipOcr
from PIL import Image

def convertimg(picfile, outdir):
#     '''调整图片大小，对于过大的图片进行压缩
#     picfile:    图片路径
#     outdir：    图片输出路径
#     '''
    img = Image.open(picfile)
    width, height = img.size
    while(width*height > 4000000):  # 该数值压缩后的图片大约 两百多k
        width = width // 2
        height = height // 2
    new_img=img.resize((width, height),Image.BILINEAR)
    new_img.save(path.join(outdir,os.path.basename(picfile)))
    
def baiduOCR(picfile, outfile):
#     """利用百度api识别文本，并保存提取的文字
#     picfile:    图片文件名
#     outfile:    输出文件
#     """
    filename = path.basename(picfile)
    
    APP_ID = '17987540' # 刚才获取的 ID，下同
    API_KEY = 'b5Xdf0gBShcbtD8ZRksHx6BM'
    SECRECT_KEY = 'Q016DUo6rl6bQON37OpPdMu7S413oPXw'
    client = AipOcr(APP_ID, API_KEY, SECRECT_KEY)
    
    i = open(picfile, 'rb')
    img = i.read()
    print("正在识别图片：\t" + filename)
#     message = client.basicGeneral(img)   # 通用文字识别，每天 50 000 次免费
    message = client.basicAccurate(img)   # 通用文字高精度识别，每天 800 次免费
    print("识别成功！")
    i.close();
    
    with open(outfile, 'a+') as fo:
        fo.writelines("+" * 60 + '\n')
        fo.writelines("识别图片：\t" + filename + "\n" * 2)
        fo.writelines("文本内容：\n")
        # 输出文本内容
        for text in message.get('words_result'):
            fo.writelines(text.get('words') + '\n')
        fo.writelines('\n'*2)
    print("文本导出成功！")
    print()

if __name__ == "__main__":
    
    outfile = 'C:/Users/swl/Desktop/2/export.txt'
    outdir = 'C:/Users/swl/Desktop/2/'
    if path.exists(outfile):
        os.remove(outfile)
    if not path.exists(outdir):
        os.mkdir(outdir)
    print("压缩过大的图片...")
#     // 首先对过大的图片进行压缩，以提高识别速度，将压缩的图片保存与临时文件夹中
    for picfile in glob.glob("C:/Users/swl/Desktop/2/*"):#图像位置
        convertimg(picfile, outdir)
    print("图片识别...")
    for picfile in glob.glob("C:/Users/swl/Desktop/2/*"):
        baiduOCR(picfile, outfile)
        os.remove(picfile)
    print('图片文本提取结束！文本输出结果位于 %s 文件中。' % outfile)
#     os.removedirs(outdir)
# Out:
# 压缩过大的图片...
# 图片识别...
# 正在识别图片：	image012.jpg
# 识别成功！
# 文本导出成功！
#
# 正在识别图片：	image013.jpg
# 识别成功！
# 文本导出成功！
#
# 正在识别图片：	image014.jpg
# 识别成功！
# 文本导出成功！
#
# 正在识别图片：	image015.jpg
# 识别成功！
# 文本导出成功！
#
# 正在识别图片：	image016.jpg
# 识别成功！
# 文本导出成功！
#
# 正在识别图片：	image017.jpg
# 识别成功！
# 文本导出成功！
#
# 正在识别图片：	image018.jpg
# 识别成功！
# 文本导出成功！
#
# 正在识别图片：	image019.jpg
# 识别成功！
# 文本导出成功！
#
# 正在识别图片：	image020.jpg
# 识别成功！
# 文本导出成功！
#
# 正在识别图片：	image021.jpg
# 识别成功！
# 文本导出成功！
#
# 正在识别图片：	image022.jpg
# 识别成功！
# 文本导出成功！
#
# 正在识别图片：	image023.jpg
# 识别成功！
# 文本导出成功！
#
# 正在识别图片：	image024.jpg
# 识别成功！
# 文本导出成功！
#
# 正在识别图片：	image025.jpg
# 识别成功！
# 文本导出成功！
#
# 正在识别图片：	image026.jpg
# 识别成功！
# 文本导出成功！
#
# 正在识别图片：	image027.jpg
# 识别成功！
# 文本导出成功！
#
# 正在识别图片：	image028.jpg
# 识别成功！
# 文本导出成功！
#
# 正在识别图片：	image029.jpg
# 识别成功！
# 文本导出成功！
#
# 正在识别图片：	image030.jpg
# 识别成功！
# 文本导出成功！
#
# 正在识别图片：	image031.jpg
# 识别成功！
# 文本导出成功！
#
# 正在识别图片：	image032.jpg
# 识别成功！
# 文本导出成功！
#
# 正在识别图片：	image033.jpg
# 识别成功！
# 文本导出成功！
#
# 正在识别图片：	image034.jpg
# ...
